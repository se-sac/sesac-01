# %%
# install
# !pip install tensorflow
# !pip install numpy
# !pip install matplotlib
# !pip install -U finance-datareader
# !pip install bs4
# !pip install pyQt6
# !pip install scikit-learn # added for "min max scaler"
# !pip install seaborn

# %%
## import librarys
import FinanceDataReader as fdr
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, GRU, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler ## added

# %%
## store in "df" (data frame)
df = fdr.DataReader('005930', '2018-05-04', '2020-01-22')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 421 entries, 2018-05-04 to 2020-01-22
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    421 non-null    int64
#  1   High    421 non-null    int64
#  2   Low     421 non-null    int64
#  3   Close   421 non-null    int64
#  4   Volume  421 non-null    int64
#  5   Change  421 non-null    float64
# dtypes: float64(1), int64(5)
# memory usage: 23.0 KB

# %%
## split x, y
target = 'Close'
dfx = df.drop(columns=[target, 'Change'])
dfy = df[[target]]
display(dfx)
display(dfy)
sns.pairplot(df)
# Out:
#              Open   High    Low    Volume
# Date
# 2018-05-04  53000  53900  51800  39565391
# 2018-05-08  52600  53200  51900  23104720
# 2018-05-09  52600  52800  50900  16128305
# 2018-05-10  51700  51700  50600  13905263
# 2018-05-11  52000  52200  51200  10314997
# ...           ...    ...    ...       ...
# 2020-01-16  59100  60700  59000  14381774
# 2020-01-17  61900  62000  61000  16025661
# 2020-01-20  62000  62800  61700  12528855
# 2020-01-21  62000  62400  61200  11142693
# 2020-01-22  60500  62600  60400  15339565
#
# [421 rows x 4 columns]
#             Close
# Date
# 2018-05-04  51900
# 2018-05-08  52600
# 2018-05-09  50900
# 2018-05-10  51600
# 2018-05-11  51300
# ...           ...
# 2020-01-16  60700
# 2020-01-17  61300
# 2020-01-20  62400
# 2020-01-21  61400
# 2020-01-22  62300
#
# [421 rows x 1 columns]

# %% [markdown]
# training dataset : 70%
# validation dataset : 20%
# tset dataset : 10%

# %%
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
x = dfx.values.tolist() # open, high, log, volumn Data
y = dfy.values.tolist() # clone Data

# %%
data_x = df.loc()
# Out:
# list

# %%
dfx.shape
# Out:
# (421, 5)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Close'], label='Close Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Close Price Over Time')
plt.legend()
plt.grid(True)
plt.show()
